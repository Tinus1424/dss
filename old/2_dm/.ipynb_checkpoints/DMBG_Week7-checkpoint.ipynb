# %% [markdown]
# ### Association rule learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.2)
from apriori_python import apriori

# %% [markdown]
# <div class="alert alert-info">Read the dataset.</div>

# %%
file = 'https://raw.githubusercontent.com/gnapoles/data-mining-course/main/credit.csv'
data = pd.read_csv(file)
data.head()
# Out:
#   checking_account_status        credit_history  gender    age  \
# 0              checking<0    not_paying_credits    male  adult
# 1            checking<200        paying_credits  female  young
# 2             no_checking    not_paying_credits    male  adult
# 3              checking<0        paying_credits    male  adult
# 4              checking<0  delay_paying_credits    male  adult
#
#                   job savings_account_status present_employment_since  \
# 0    skilled_employee             no_savings             employed>=7y
# 1    skilled_employee            savings<100              employed<4y
# 2  unskilled_employee            savings<100              employed<7y
# 3    skilled_employee            savings<100              employed<7y
# 4    skilled_employee            savings<100              employed<4y
#
#   other_debtors/guarantors     housing  foreign_worker             class
# 0               no_debtors   own_house  foreign_worker  good_credit_risk
# 1               no_debtors   own_house  foreign_worker   bad_credit_risk
# 2               no_debtors   own_house  foreign_worker  good_credit_risk
# 3                guarantor  free_house  foreign_worker  good_credit_risk
# 4               no_debtors  free_house  foreign_worker   bad_credit_risk

# %%
def plot_heatmap(data, groupby_col, ax):
    cf_comp = data.groupby([groupby_col, 'class']).size().unstack(fill_value=0)
    ax = sns.heatmap(cf_comp, annot=True, cmap='coolwarm', ax=ax, fmt='d')
    ax.set_xticklabels(["Bad", "Good"])
    ax.set_yticklabels(["Female" if groupby_col == "gender" else "Adult" if groupby_col == "age" else "Foreign", "Male" if groupby_col == "gender" else "Young" if groupby_col == "age" else "Native"])
    ax.set_xlabel("Credit Class")
    ax.set_ylabel("Group")

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
groupby_cols = ['gender', 'age', 'foreign_worker']

for i, groupby_col in enumerate(groupby_cols):
    plot_heatmap(data, groupby_col, axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">Exercise 1:Given the tables, compute the good credit rates for native and foreign applicants?</div>

# %%
records = data.to_numpy().tolist()

# %%
freqItemSet, rules = apriori(records, minSup=0.5, minConf=0.2)

# %%
def print_selected_rules(rules, target_class=None, keyword=None):
    rule_number = 1
    for i, rule in enumerate(rules):
        antecedent, consequent, confidence = rule

        # Check if the rule's consequent matches the target_class
        if len(consequent) == 1 and (target_class is None or target_class in consequent):
            # Check if the keyword (if provided) is in the rule's antecedent
            if keyword is None or keyword in antecedent:
                print(f"Rule {rule_number}: {antecedent} → {consequent}")
                print(f"\tConfidence = {round(confidence, 2)}")
                rule_number += 1

# Example usage:
print_selected_rules(rules, target_class="good_credit_risk")
# Out:
# Rule 1: {'foreign_worker'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 2: {'foreign_worker', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 3: {'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 4: {'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 5: {'foreign_worker', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 6: {'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 7: {'adult'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 8: {'foreign_worker', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 9: {'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74

# %% [markdown]
# <div class="alert alert-warning">Exercise 2
# Interpret the rule #4?</div>

# %%
freqItemSet, rules = apriori(records, minSup=0.1, minConf=0.2)
print_selected_rules(rules, target_class="good_credit_risk")
# Out:
# Rule 1: {'foreign_worker', 'checking<0', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.47
# Rule 2: {'checking<0', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.48
# Rule 3: {'foreign_worker', 'checking<0'} → {'good_credit_risk'}
# 	Confidence = 0.49
# Rule 4: {'checking<0', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.49
# Rule 5: {'checking<0'} → {'good_credit_risk'}
# 	Confidence = 0.51
# Rule 6: {'foreign_worker', 'adult', 'checking<0'} → {'good_credit_risk'}
# 	Confidence = 0.51
# Rule 7: {'adult', 'checking<0'} → {'good_credit_risk'}
# 	Confidence = 0.53
# Rule 8: {'employed<1y'} → {'good_credit_risk'}
# 	Confidence = 0.59
# Rule 9: {'foreign_worker', 'rent_house'} → {'good_credit_risk'}
# 	Confidence = 0.59
# Rule 10: {'female', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.6
# Rule 11: {'checking<200', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.6
# Rule 12: {'foreign_worker', 'checking<200', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.6
# Rule 13: {'foreign_worker', 'female', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.6
# Rule 14: {'paying_credits', 'foreign_worker', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 15: {'paying_credits', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 16: {'female', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 17: {'rent_house'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 18: {'adult', 'checking<200', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 19: {'checking<200'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 20: {'foreign_worker', 'checking<200'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 21: {'female', 'foreign_worker', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 22: {'foreign_worker', 'checking<200', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 23: {'no_debtors', 'skilled_employee', 'foreign_worker', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.61
# Rule 24: {'paying_credits', 'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 25: {'paying_credits', 'foreign_worker', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 26: {'paying_credits', 'female', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 27: {'foreign_worker', 'female', 'no_debtors', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 28: {'foreign_worker', 'male', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 29: {'no_debtors', 'skilled_employee', 'foreign_worker', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 30: {'adult', 'checking<200'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 31: {'paying_credits', 'foreign_worker', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 32: {'paying_credits', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 33: {'foreign_worker', 'checking<200', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.62
# Rule 34: {'foreign_worker', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 35: {'foreign_worker', 'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 36: {'foreign_worker', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 37: {'male', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 38: {'paying_credits', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 39: {'paying_credits', 'female'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 40: {'male', 'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 41: {'female', 'foreign_worker', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 42: {'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 43: {'skilled_employee', 'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 44: {'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 45: {'foreign_worker', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 46: {'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.63
# Rule 47: {'no_debtors', 'foreign_worker', 'male', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 48: {'no_debtors', 'own_house', 'foreign_worker', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 49: {'no_debtors', 'foreign_worker', 'adult', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 50: {'rent_house', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 51: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 52: {'paying_credits', 'adult', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 53: {'paying_credits', 'no_debtors', 'own_house', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 54: {'adult', 'male', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 55: {'checking<200', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 56: {'foreign_worker', 'male', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 57: {'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 58: {'foreign_worker', 'checking<200', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 59: {'paying_credits', 'male', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 60: {'checking<200', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 61: {'foreign_worker', 'checking<200', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 62: {'foreign_worker', 'checking<200', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 63: {'foreign_worker', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 64: {'foreign_worker', 'adult', 'male', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 65: {'paying_credits', 'foreign_worker', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.64
# Rule 66: {'no_debtors', 'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 67: {'no_debtors', 'skilled_employee', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 68: {'foreign_worker', 'adult', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 69: {'paying_credits', 'employed<4y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 70: {'paying_credits', 'foreign_worker', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 71: {'female', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 72: {'foreign_worker', 'female'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 73: {'female', 'foreign_worker', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 74: {'female'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 75: {'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 76: {'foreign_worker', 'employed<4y', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 77: {'checking<200', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 78: {'no_debtors', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 79: {'no_debtors', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 80: {'foreign_worker', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 81: {'employed<4y', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.65
# Rule 82: {'paying_credits', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 83: {'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 84: {'paying_credits', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 85: {'paying_credits', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 86: {'checking<200', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 87: {'foreign_worker', 'adult', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 88: {'adult', 'male', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 89: {'paying_credits', 'foreign_worker', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 90: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 91: {'foreign_worker', 'checking<200', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 92: {'paying_credits', 'foreign_worker', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 93: {'skilled_employee', 'own_house', 'foreign_worker', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 94: {'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 95: {'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 96: {'foreign_worker', 'female', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 97: {'adult', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 98: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 99: {'foreign_worker', 'checking<200', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 100: {'adult', 'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 101: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 102: {'paying_credits', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 103: {'foreign_worker', 'employed<4y', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 104: {'paying_credits', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 105: {'no_debtors', 'own_house', 'adult', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 106: {'female', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.66
# Rule 107: {'foreign_worker', 'no_debtors', 'own_house', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 108: {'employed<4y', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 109: {'adult', 'checking<200', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 110: {'female', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 111: {'foreign_worker', 'female', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 112: {'no_debtors', 'own_house', 'foreign_worker', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 113: {'foreign_worker', 'female', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 114: {'female', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 115: {'no_debtors', 'skilled_employee', 'own_house', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 116: {'own_house', 'male', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 117: {'no_debtors', 'own_house', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 118: {'paying_credits', 'foreign_worker', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 119: {'paying_credits', 'foreign_worker'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 120: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 121: {'foreign_worker', 'male', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 122: {'paying_credits', 'foreign_worker', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.67
# Rule 123: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 124: {'female', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 125: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 126: {'foreign_worker', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 127: {'female', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 128: {'paying_credits', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 129: {'male', 'no_debtors', 'own_house', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 130: {'foreign_worker', 'own_house', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 131: {'own_house', 'foreign_worker', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 132: {'paying_credits', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 133: {'adult', 'checking<200', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 134: {'own_house', 'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 135: {'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 136: {'paying_credits', 'foreign_worker', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 137: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 138: {'own_house', 'foreign_worker', 'adult', 'savings<100', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 139: {'foreign_worker', 'adult', 'employed<4y', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 140: {'foreign_worker', 'checking<200', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 141: {'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 142: {'adult', 'employed<4y', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 143: {'own_house', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.68
# Rule 144: {'female', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 145: {'skilled_employee', 'own_house', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 146: {'paying_credits', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 147: {'foreign_worker', 'employed<4y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 148: {'male', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 149: {'foreign_worker', 'employed<4y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 150: {'no_debtors', 'own_house', 'adult', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 151: {'foreign_worker', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 152: {'adult', 'no_debtors', 'own_house', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 153: {'paying_credits', 'adult', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 154: {'foreign_worker', 'female', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 155: {'foreign_worker', 'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 156: {'unskilled_employee', 'foreign_worker', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 157: {'paying_credits', 'male', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 158: {'paying_credits', 'adult', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 159: {'employed<4y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 160: {'foreign_worker', 'adult', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 161: {'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 162: {'adult', 'male', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 163: {'employed<4y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 164: {'foreign_worker'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 165: {'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 166: {'paying_credits', 'foreign_worker', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 167: {'foreign_worker', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.69
# Rule 168: {'paying_credits', 'foreign_worker', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 169: {'adult', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 170: {'foreign_worker', 'employed<4y', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 171: {'paying_credits', 'foreign_worker', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 172: {'paying_credits', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 173: {'foreign_worker', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 174: {'unskilled_employee', 'foreign_worker'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 175: {'female', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 176: {'employed<4y', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 177: {'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 178: {'paying_credits', 'foreign_worker', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 179: {'foreign_worker', 'adult', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 180: {'foreign_worker', 'female', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 181: {'paying_credits', 'foreign_worker', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 182: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 183: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 184: {'paying_credits', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 185: {'foreign_worker', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 186: {'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.7
# Rule 187: {'unskilled_employee', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 188: {'no_debtors', 'skilled_employee', 'own_house', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 189: {'own_house', 'adult', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 190: {'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 191: {'paying_credits', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 192: {'paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 193: {'paying_credits', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 194: {'foreign_worker', 'adult', 'employed<4y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 195: {'paying_credits', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 196: {'female', 'adult', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 197: {'no_debtors', 'skilled_employee', 'employed<4y', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 198: {'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 199: {'foreign_worker', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 200: {'foreign_worker', 'adult', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 201: {'foreign_worker', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 202: {'adult', 'employed<4y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 203: {'paying_credits', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 204: {'paying_credits', 'foreign_worker', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.71
# Rule 205: {'female', 'no_debtors', 'own_house', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 206: {'foreign_worker', 'employed<4y', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 207: {'foreign_worker', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 208: {'no_debtors', 'employed<4y', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 209: {'adult', 'employed<4y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 210: {'unskilled_employee', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 211: {'foreign_worker', 'employed<4y', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 212: {'foreign_worker', 'adult', 'employed<4y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 213: {'foreign_worker', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 214: {'foreign_worker', 'employed<4y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 215: {'foreign_worker', 'own_house', 'skilled_employee', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 216: {'adult', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 217: {'foreign_worker', 'adult', 'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 218: {'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 219: {'adult'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 220: {'adult', 'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 221: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 222: {'unskilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 223: {'paying_credits', 'foreign_worker', 'adult', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 224: {'foreign_worker', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 225: {'unskilled_employee', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 226: {'employed<4y', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 227: {'paying_credits', 'foreign_worker', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 228: {'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 229: {'no_debtors', 'foreign_worker', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 230: {'male'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 231: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 232: {'paying_credits', 'own_house', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 233: {'paying_credits', 'own_house', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 234: {'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.72
# Rule 235: {'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 236: {'paying_credits', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 237: {'foreign_worker', 'adult', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 238: {'paying_credits', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 239: {'female', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 240: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 241: {'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 242: {'paying_credits', 'adult', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 243: {'no_debtors', 'own_house', 'foreign_worker', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 244: {'paying_credits', 'adult', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 245: {'employed<4y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 246: {'no_debtors', 'skilled_employee', 'foreign_worker', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 247: {'foreign_worker', 'adult', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 248: {'employed<4y', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 249: {'foreign_worker', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 250: {'adult', 'employed<4y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 251: {'foreign_worker', 'employed<4y', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 252: {'paying_credits', 'foreign_worker', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 253: {'foreign_worker', 'female', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 254: {'employed<4y', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 255: {'foreign_worker', 'adult', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 256: {'paying_credits', 'adult', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 257: {'adult', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 258: {'paying_credits', 'adult', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 259: {'adult', 'employed<4y', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 260: {'foreign_worker', 'employed<4y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 261: {'foreign_worker', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 262: {'employed<4y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 263: {'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 264: {'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 265: {'foreign_worker', 'adult', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.73
# Rule 266: {'paying_credits', 'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 267: {'paying_credits', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 268: {'adult', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 269: {'paying_credits', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 270: {'unskilled_employee', 'foreign_worker', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 271: {'no_debtors', 'skilled_employee', 'employed<4y', 'own_house', 'foreign_worker'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 272: {'own_house', 'employed<4y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 273: {'unskilled_employee', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 274: {'paying_credits', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 275: {'adult', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 276: {'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 277: {'foreign_worker', 'own_house', 'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 278: {'adult', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 279: {'own_house', 'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 280: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 281: {'employed>=7y', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 282: {'foreign_worker', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.74
# Rule 283: {'adult', 'employed>=7y'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 284: {'foreign_worker', 'employed>=7y'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 285: {'foreign_worker', 'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 286: {'employed>=7y'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 287: {'own_house', 'foreign_worker', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 288: {'adult', 'employed>=7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 289: {'employed>=7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 290: {'adult', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 291: {'foreign_worker', 'adult', 'employed>=7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 292: {'foreign_worker', 'employed>=7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 293: {'unskilled_employee', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 294: {'adult', 'employed<4y', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 295: {'no_debtors', 'employed<4y', 'own_house', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 296: {'skilled_employee', 'own_house', 'foreign_worker', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 297: {'foreign_worker', 'adult', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 298: {'foreign_worker', 'own_house', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 299: {'foreign_worker', 'adult', 'employed<4y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 300: {'foreign_worker', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 301: {'adult', 'employed<4y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 302: {'skilled_employee', 'foreign_worker', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 303: {'foreign_worker', 'employed<4y', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 304: {'foreign_worker', 'own_house', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 305: {'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 306: {'unskilled_employee', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 307: {'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.75
# Rule 308: {'no_debtors', 'employed<4y', 'own_house', 'foreign_worker', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 309: {'adult', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 310: {'foreign_worker', 'employed>=7y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 311: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 312: {'own_house', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 313: {'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 314: {'employed>=7y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 315: {'own_house', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 316: {'paying_credits', 'adult', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 317: {'employed<4y', 'own_house', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 318: {'foreign_worker', 'adult', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 319: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 320: {'foreign_worker', 'adult', 'employed>=7y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 321: {'paying_credits', 'own_house', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 322: {'adult', 'employed>=7y', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 323: {'foreign_worker', 'own_house', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 324: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 325: {'paying_credits', 'own_house', 'adult', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 326: {'employed<4y', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 327: {'employed>=7y', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 328: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 329: {'paying_credits', 'adult', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 330: {'foreign_worker', 'employed>=7y', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 331: {'employed<4y', 'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.76
# Rule 332: {'no_debtors', 'skilled_employee', 'own_house', 'adult', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 333: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 334: {'skilled_employee', 'employed<4y', 'own_house', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 335: {'foreign_worker', 'employed<7y'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 336: {'no_debtors', 'own_house', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 337: {'adult', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 338: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 339: {'own_house', 'adult', 'employed<4y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 340: {'unskilled_employee', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 341: {'adult', 'employed>=7y', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 342: {'own_house', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 343: {'adult', 'employed<4y', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 344: {'adult', 'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 345: {'no_debtors', 'employed>=7y', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 346: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 347: {'own_house', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 348: {'no_debtors', 'skilled_employee', 'own_house', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 349: {'foreign_worker', 'own_house', 'adult', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.77
# Rule 350: {'foreign_worker', 'employed>=7y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 351: {'employed<7y'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 352: {'no_debtors', 'employed<4y', 'own_house', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 353: {'foreign_worker', 'adult', 'employed>=7y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 354: {'employed>=7y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 355: {'foreign_worker', 'employed>=7y', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 356: {'no_debtors', 'skilled_employee', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 357: {'adult', 'employed>=7y', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 358: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 359: {'adult', 'own_house', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 360: {'employed>=7y', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 361: {'foreign_worker', 'not_paying_credits', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 362: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 363: {'foreign_worker', 'employed<7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 364: {'own_house', 'adult', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 365: {'skilled_employee', 'employed>=7y', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.78
# Rule 366: {'foreign_worker', 'adult', 'savings<100', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 367: {'adult', 'employed>=7y', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 368: {'not_paying_credits', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 369: {'employed<7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 370: {'own_house', 'adult', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 371: {'foreign_worker', 'employed>=7y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 372: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 373: {'employed>=7y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 374: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 375: {'employed<7y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 376: {'not_paying_credits', 'adult', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 377: {'no_debtors', 'skilled_employee', 'employed>=7y', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.79
# Rule 378: {'not_paying_credits', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 379: {'foreign_worker', 'not_paying_credits', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 380: {'adult', 'employed>=7y', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 381: {'no_debtors', 'skilled_employee', 'own_house', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 382: {'foreign_worker', 'adult', 'employed<7y'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 383: {'employed>=7y', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 384: {'skilled_employee', 'own_house', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 385: {'foreign_worker', 'not_paying_credits', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 386: {'not_paying_credits', 'adult', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.8
# Rule 387: {'not_paying_credits', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 388: {'adult', 'employed>=7y', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 389: {'no_debtors', 'foreign_worker', 'adult', 'not_paying_credits', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 390: {'adult', 'employed<7y'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 391: {'no_debtors', 'employed>=7y', 'own_house', 'foreign_worker', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 392: {'adult', 'employed>=7y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 393: {'foreign_worker', 'adult', 'employed>=7y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 394: {'employed>=7y', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 395: {'no_debtors', 'not_paying_credits', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 396: {'employed>=7y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 397: {'foreign_worker', 'employed>=7y', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 398: {'foreign_worker', 'employed>=7y', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.81
# Rule 399: {'no_savings', 'foreign_worker', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 400: {'no_debtors', 'employed>=7y', 'own_house', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 401: {'employed>=7y', 'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 402: {'adult', 'employed>=7y', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 403: {'no_savings', 'foreign_worker'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 404: {'employed>=7y', 'own_house', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 405: {'employed>=7y', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 406: {'adult', 'not_paying_credits', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 407: {'foreign_worker', 'adult', 'employed<7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 408: {'foreign_worker', 'employed>=7y', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 409: {'no_debtors', 'employed>=7y', 'own_house', 'foreign_worker', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 410: {'no_savings', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 411: {'no_debtors', 'employed>=7y', 'own_house', 'foreign_worker', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 412: {'no_savings', 'foreign_worker', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 413: {'foreign_worker', 'adult', 'no_savings'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 414: {'no_debtors', 'skilled_employee', 'own_house', 'adult', 'male', 'paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 415: {'foreign_worker', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.82
# Rule 416: {'no_savings'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 417: {'adult', 'employed<7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 418: {'no_savings', 'adult', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 419: {'no_savings', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 420: {'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 421: {'no_savings', 'foreign_worker', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 422: {'adult', 'not_paying_credits', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 423: {'not_paying_credits', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 424: {'skilled_employee', 'foreign_worker', 'adult', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.83
# Rule 425: {'foreign_worker', 'not_paying_credits', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 426: {'foreign_worker', 'adult', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 427: {'foreign_worker', 'not_paying_credits', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 428: {'foreign_worker', 'not_paying_credits', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 429: {'no_savings', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 430: {'foreign_worker', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 431: {'not_paying_credits', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 432: {'no_savings', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 433: {'adult', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 434: {'foreign_worker', 'adult', 'male', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 435: {'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 436: {'not_paying_credits', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 437: {'foreign_worker', 'adult', 'not_paying_credits', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 438: {'adult', 'not_paying_credits', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 439: {'adult', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.84
# Rule 440: {'foreign_worker', 'employed<4y', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 441: {'foreign_worker', 'not_paying_credits', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 442: {'foreign_worker', 'employed<4y', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 443: {'foreign_worker', 'adult', 'no_debtors', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 444: {'foreign_worker', 'not_paying_credits', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 445: {'no_savings', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 446: {'foreign_worker', 'adult', 'employed<4y', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 447: {'no_debtors', 'skilled_employee', 'foreign_worker', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 448: {'no_savings', 'foreign_worker', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 449: {'foreign_worker', 'not_paying_credits', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 450: {'foreign_worker', 'not_paying_credits', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 451: {'not_paying_credits', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 452: {'no_savings', 'foreign_worker', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 453: {'foreign_worker', 'adult', 'not_paying_credits', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 454: {'not_paying_credits', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 455: {'foreign_worker', 'not_paying_credits', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 456: {'no_debtors', 'skilled_employee', 'not_paying_credits', 'adult', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 457: {'no_savings', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 458: {'no_checking', 'employed<4y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.85
# Rule 459: {'not_paying_credits', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 460: {'adult', 'not_paying_credits', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 461: {'no_debtors', 'foreign_worker', 'adult', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 462: {'no_checking', 'employed<4y'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 463: {'not_paying_credits', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 464: {'no_debtors', 'own_house', 'foreign_worker', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 465: {'no_savings', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 466: {'adult', 'employed<4y', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 467: {'not_paying_credits', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 468: {'adult', 'employed<4y', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 469: {'own_house', 'foreign_worker', 'adult', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 470: {'not_paying_credits', 'adult', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.86
# Rule 471: {'not_paying_credits', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.86
# ...
# Rule 494: {'no_debtors', 'own_house', 'foreign_worker', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.87
# Rule 495: {'foreign_worker', 'no_checking', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.87
# Rule 496: {'no_debtors', 'foreign_worker', 'male', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.87
# Rule 497: {'no_checking', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.87
# Rule 498: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.87
# Rule 499: {'no_debtors', 'own_house', 'adult', 'not_paying_credits', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.87
# Rule 500: {'own_house', 'adult', 'not_paying_credits', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 501: {'foreign_worker', 'adult', 'male', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 502: {'no_checking', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 503: {'no_checking', 'no_debtors', 'own_house', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 504: {'no_checking', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 505: {'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 506: {'own_house', 'not_paying_credits', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 507: {'no_checking', 'male', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 508: {'adult', 'no_checking', 'male', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 509: {'foreign_worker', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 510: {'no_debtors', 'skilled_employee', 'foreign_worker', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 511: {'no_debtors', 'adult', 'male', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 512: {'paying_credits', 'foreign_worker', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 513: {'no_checking', 'no_debtors', 'skilled_employee', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 514: {'paying_credits', 'foreign_worker', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 515: {'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 516: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'not_paying_credits'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 517: {'foreign_worker', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.88
# Rule 518: {'no_debtors', 'foreign_worker', 'adult', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 519: {'foreign_worker', 'adult', 'no_checking', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 520: {'paying_credits', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 521: {'own_house', 'foreign_worker', 'adult', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 522: {'paying_credits', 'foreign_worker', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 523: {'no_debtors', 'skilled_employee', 'own_house', 'not_paying_credits', 'adult'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 524: {'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 525: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 526: {'adult', 'no_checking', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 527: {'adult', 'no_checking', 'no_debtors', 'savings<100'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 528: {'own_house', 'foreign_worker', 'adult', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 529: {'foreign_worker', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 530: {'paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 531: {'adult', 'no_checking', 'savings<100', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 532: {'foreign_worker', 'adult', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 533: {'no_debtors', 'foreign_worker', 'adult', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 534: {'no_debtors', 'own_house', 'adult', 'savings<100', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 535: {'paying_credits', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 536: {'foreign_worker', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 537: {'paying_credits', 'foreign_worker', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 538: {'no_debtors', 'own_house', 'foreign_worker', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 539: {'foreign_worker', 'no_checking', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 540: {'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 541: {'adult', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 542: {'paying_credits', 'adult', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 543: {'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 544: {'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 545: {'foreign_worker', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 546: {'foreign_worker', 'adult', 'male', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.89
# Rule 547: {'foreign_worker', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 548: {'paying_credits', 'adult', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 549: {'foreign_worker', 'adult', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 550: {'paying_credits', 'no_checking', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 551: {'paying_credits', 'foreign_worker', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 552: {'no_checking', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 553: {'no_debtors', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 554: {'foreign_worker', 'no_checking', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 555: {'foreign_worker', 'no_checking', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 556: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 557: {'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 558: {'adult', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 559: {'paying_credits', 'no_checking', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 560: {'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 561: {'no_checking', 'male'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 562: {'paying_credits', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 563: {'no_checking', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 564: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 565: {'adult', 'no_checking', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 566: {'no_checking', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 567: {'adult', 'no_checking', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 568: {'paying_credits', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 569: {'no_debtors', 'foreign_worker', 'male', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.9
# Rule 570: {'no_debtors', 'own_house', 'adult', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 571: {'no_debtors', 'skilled_employee', 'foreign_worker', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 572: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 573: {'foreign_worker', 'male', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 574: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 575: {'own_house', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 576: {'paying_credits', 'no_checking', 'male', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 577: {'paying_credits', 'no_checking', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 578: {'own_house', 'no_checking', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 579: {'no_checking', 'male', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 580: {'adult', 'no_checking', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 581: {'foreign_worker', 'own_house', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 582: {'no_debtors', 'skilled_employee', 'foreign_worker', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 583: {'no_debtors', 'own_house', 'foreign_worker', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 584: {'foreign_worker', 'adult', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 585: {'adult', 'male', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 586: {'no_checking', 'own_house', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 587: {'no_debtors', 'adult', 'male', 'paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 588: {'no_debtors', 'skilled_employee', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 589: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 590: {'no_checking', 'male', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 591: {'no_checking', 'male', 'no_debtors', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 592: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 593: {'adult', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.91
# Rule 594: {'foreign_worker', 'male', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 595: {'no_debtors', 'skilled_employee', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 596: {'no_debtors', 'own_house', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 597: {'no_debtors', 'skilled_employee', 'own_house', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 598: {'skilled_employee', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 599: {'adult', 'no_checking', 'savings<100', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 600: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 601: {'no_checking', 'male', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 602: {'adult', 'male', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 603: {'own_house', 'adult', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.92
# Rule 604: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 605: {'adult', 'employed>=7y', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 606: {'foreign_worker', 'employed>=7y', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 607: {'no_checking', 'employed>=7y', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 608: {'foreign_worker', 'adult', 'employed>=7y', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 609: {'paying_credits', 'adult', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 610: {'no_debtors', 'skilled_employee', 'own_house', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 611: {'skilled_employee', 'own_house', 'foreign_worker', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 612: {'adult', 'employed>=7y', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 613: {'foreign_worker', 'employed>=7y', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 614: {'no_debtors', 'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 615: {'foreign_worker', 'not_paying_credits', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 616: {'no_checking', 'employed>=7y'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 617: {'not_paying_credits', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 618: {'own_house', 'male', 'no_checking', 'skilled_employee'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 619: {'no_debtors', 'skilled_employee', 'own_house', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 620: {'foreign_worker', 'not_paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 621: {'skilled_employee', 'own_house', 'foreign_worker', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 622: {'not_paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.93
# Rule 623: {'skilled_employee', 'own_house', 'adult', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.94
# Rule 624: {'no_debtors', 'foreign_worker', 'not_paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.94
# Rule 625: {'not_paying_credits', 'adult', 'no_checking', 'no_debtors'} → {'good_credit_risk'}
# 	Confidence = 0.94
# Rule 626: {'foreign_worker', 'not_paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.94
# Rule 627: {'not_paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.94
# Rule 628: {'no_debtors', 'own_house', 'foreign_worker', 'not_paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 629: {'no_debtors', 'own_house', 'not_paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 630: {'no_debtors', 'own_house', 'foreign_worker', 'not_paying_credits', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 631: {'own_house', 'foreign_worker', 'not_paying_credits', 'adult', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 632: {'not_paying_credits', 'no_checking', 'no_debtors', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 633: {'not_paying_credits', 'adult', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 634: {'foreign_worker', 'not_paying_credits', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 635: {'not_paying_credits', 'no_checking', 'own_house'} → {'good_credit_risk'}
# 	Confidence = 0.95
# Rule 636: {'not_paying_credits', 'male', 'no_checking'} → {'good_credit_risk'}
# 	Confidence = 0.95

# %%
freqItemSet, rules = apriori(records, minSup=0.5, minConf=0.2)
print_selected_rules(rules, "female")

# %% [markdown]
# <div class="alert alert-warning">Exercise 3
# How many rules do you expect to extract once you run the code below?</div>

# %%
freqItemSet, rules = apriori(records, minSup=0.35, minConf=0.2)
print_selected_rules(rules, "female")

# %%
freqItemSet, rules = apriori(records, minSup=0.1, minConf=0.2)
print_selected_rules(rules, "female")
# Out:
# Rule 1: {'adult', 'good_credit_risk', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.24
# Rule 2: {'adult', 'good_credit_risk', 'own_house'} → {'female'}
# 	Confidence = 0.24
# Rule 3: {'no_debtors', 'own_house', 'foreign_worker', 'adult', 'good_credit_risk'} → {'female'}
# 	Confidence = 0.25
# Rule 4: {'adult', 'good_credit_risk', 'no_debtors'} → {'female'}
# 	Confidence = 0.25
# Rule 5: {'foreign_worker', 'adult', 'good_credit_risk', 'own_house'} → {'female'}
# 	Confidence = 0.25
# Rule 6: {'adult', 'good_credit_risk'} → {'female'}
# 	Confidence = 0.25
# Rule 7: {'adult', 'own_house'} → {'female'}
# 	Confidence = 0.25
# Rule 8: {'foreign_worker', 'adult', 'good_credit_risk', 'no_debtors'} → {'female'}
# 	Confidence = 0.25
# Rule 9: {'foreign_worker', 'adult', 'own_house'} → {'female'}
# 	Confidence = 0.25
# Rule 10: {'adult', 'own_house', 'skilled_employee'} → {'female'}
# 	Confidence = 0.26
# Rule 11: {'foreign_worker', 'adult', 'good_credit_risk'} → {'female'}
# 	Confidence = 0.26
# Rule 12: {'adult', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.26
# Rule 13: {'foreign_worker', 'adult', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.26
# Rule 14: {'foreign_worker', 'adult', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.26
# Rule 15: {'foreign_worker', 'adult', 'skilled_employee'} → {'female'}
# 	Confidence = 0.26
# Rule 16: {'good_credit_risk', 'own_house'} → {'female'}
# 	Confidence = 0.26
# Rule 17: {'adult', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.26
# Rule 18: {'adult', 'skilled_employee'} → {'female'}
# 	Confidence = 0.26
# Rule 19: {'good_credit_risk', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.26
# Rule 20: {'foreign_worker', 'good_credit_risk', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.27
# Rule 21: {'adult'} → {'female'}
# 	Confidence = 0.27
# Rule 22: {'foreign_worker', 'good_credit_risk', 'own_house'} → {'female'}
# 	Confidence = 0.27
# Rule 23: {'adult', 'no_debtors'} → {'female'}
# 	Confidence = 0.27
# Rule 24: {'foreign_worker', 'adult'} → {'female'}
# 	Confidence = 0.27
# Rule 25: {'foreign_worker', 'adult', 'no_debtors'} → {'female'}
# 	Confidence = 0.27
# Rule 26: {'adult', 'savings<100', 'own_house'} → {'female'}
# 	Confidence = 0.27
# Rule 27: {'own_house'} → {'female'}
# 	Confidence = 0.27
# Rule 28: {'foreign_worker', 'adult', 'savings<100', 'own_house'} → {'female'}
# 	Confidence = 0.28
# Rule 29: {'adult', 'savings<100'} → {'female'}
# 	Confidence = 0.28
# Rule 30: {'adult', 'no_debtors', 'savings<100'} → {'female'}
# 	Confidence = 0.28
# Rule 31: {'foreign_worker', 'own_house'} → {'female'}
# 	Confidence = 0.28
# Rule 32: {'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.28
# Rule 33: {'foreign_worker', 'own_house', 'skilled_employee'} → {'female'}
# 	Confidence = 0.28
# Rule 34: {'own_house', 'skilled_employee'} → {'female'}
# 	Confidence = 0.28
# Rule 35: {'foreign_worker', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.28
# Rule 36: {'foreign_worker', 'own_house', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.28
# Rule 37: {'foreign_worker', 'adult', 'no_debtors', 'savings<100'} → {'female'}
# 	Confidence = 0.28
# Rule 38: {'foreign_worker', 'adult', 'savings<100'} → {'female'}
# 	Confidence = 0.28
# Rule 39: {'own_house', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.28
# Rule 40: {'good_credit_risk'} → {'female'}
# 	Confidence = 0.29
# Rule 41: {'good_credit_risk', 'no_debtors'} → {'female'}
# 	Confidence = 0.29
# Rule 42: {'foreign_worker', 'good_credit_risk'} → {'female'}
# 	Confidence = 0.29
# Rule 43: {'no_checking'} → {'female'}
# 	Confidence = 0.29
# Rule 44: {'good_credit_risk', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.29
# Rule 45: {'foreign_worker', 'good_credit_risk', 'no_debtors'} → {'female'}
# 	Confidence = 0.29
# Rule 46: {'no_checking', 'no_debtors'} → {'female'}
# 	Confidence = 0.29
# Rule 47: {'good_credit_risk', 'skilled_employee'} → {'female'}
# 	Confidence = 0.3
# Rule 48: {'foreign_worker', 'good_credit_risk', 'skilled_employee'} → {'female'}
# 	Confidence = 0.3
# Rule 49: {'foreign_worker', 'good_credit_risk', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.3
# Rule 50: {'paying_credits', 'adult'} → {'female'}
# 	Confidence = 0.3
# Rule 51: {'savings<100', 'own_house'} → {'female'}
# 	Confidence = 0.3
# Rule 52: {'paying_credits', 'adult', 'no_debtors'} → {'female'}
# 	Confidence = 0.3
# Rule 53: {'no_debtors', 'savings<100', 'own_house'} → {'female'}
# 	Confidence = 0.3
# Rule 54: {'foreign_worker', 'savings<100', 'own_house'} → {'female'}
# 	Confidence = 0.3
# Rule 55: {'foreign_worker', 'no_checking', 'no_debtors'} → {'female'}
# 	Confidence = 0.3
# Rule 56: {'foreign_worker', 'no_checking'} → {'female'}
# 	Confidence = 0.3
# Rule 57: {'good_credit_risk', 'no_debtors', 'savings<100'} → {'female'}
# 	Confidence = 0.3
# Rule 58: {'paying_credits', 'foreign_worker', 'adult'} → {'female'}
# 	Confidence = 0.3
# Rule 59: {'foreign_worker', 'no_debtors', 'own_house', 'savings<100'} → {'female'}
# 	Confidence = 0.3
# Rule 60: {'paying_credits', 'foreign_worker', 'adult', 'no_debtors'} → {'female'}
# 	Confidence = 0.3
# Rule 61: {'good_credit_risk', 'savings<100'} → {'female'}
# 	Confidence = 0.31
# Rule 62: {'foreign_worker', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.31
# Rule 63: {'no_debtors'} → {'female'}
# 	Confidence = 0.31
# Rule 64: {'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.31
# Rule 65: {'paying_credits', 'own_house'} → {'female'}
# 	Confidence = 0.31
# Rule 66: {'foreign_worker', 'skilled_employee'} → {'female'}
# 	Confidence = 0.31
# Rule 67: {'foreign_worker', 'good_credit_risk', 'no_debtors', 'savings<100'} → {'female'}
# 	Confidence = 0.31
# Rule 68: {'skilled_employee'} → {'female'}
# 	Confidence = 0.31
# Rule 69: {'foreign_worker'} → {'female'}
# 	Confidence = 0.31
# Rule 70: {'foreign_worker', 'good_credit_risk', 'savings<100'} → {'female'}
# 	Confidence = 0.32
# Rule 71: {'employed<4y'} → {'female'}
# 	Confidence = 0.32
# Rule 72: {'foreign_worker', 'no_debtors'} → {'female'}
# 	Confidence = 0.32
# Rule 73: {'paying_credits', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.32
# Rule 74: {'no_debtors', 'savings<100'} → {'female'}
# 	Confidence = 0.32
# Rule 75: {'savings<100'} → {'female'}
# 	Confidence = 0.32
# Rule 76: {'paying_credits', 'foreign_worker', 'own_house'} → {'female'}
# 	Confidence = 0.32
# Rule 77: {'foreign_worker', 'employed<4y'} → {'female'}
# 	Confidence = 0.32
# Rule 78: {'paying_credits', 'good_credit_risk'} → {'female'}
# 	Confidence = 0.32
# Rule 79: {'paying_credits', 'good_credit_risk', 'no_debtors'} → {'female'}
# 	Confidence = 0.33
# Rule 80: {'paying_credits', 'foreign_worker', 'no_debtors', 'own_house'} → {'female'}
# 	Confidence = 0.33
# Rule 81: {'foreign_worker', 'no_debtors', 'savings<100'} → {'female'}
# 	Confidence = 0.33
# Rule 82: {'foreign_worker', 'savings<100'} → {'female'}
# 	Confidence = 0.33
# Rule 83: {'paying_credits', 'foreign_worker', 'good_credit_risk', 'no_debtors'} → {'female'}
# 	Confidence = 0.33
# Rule 84: {'paying_credits', 'foreign_worker', 'good_credit_risk'} → {'female'}
# 	Confidence = 0.34
# Rule 85: {'no_debtors', 'skilled_employee', 'savings<100'} → {'female'}
# 	Confidence = 0.34
# Rule 86: {'foreign_worker', 'no_debtors', 'skilled_employee', 'savings<100'} → {'female'}
# 	Confidence = 0.34
# Rule 87: {'savings<100', 'skilled_employee'} → {'female'}
# 	Confidence = 0.34
# Rule 88: {'foreign_worker', 'savings<100', 'skilled_employee'} → {'female'}
# 	Confidence = 0.34
# Rule 89: {'paying_credits'} → {'female'}
# 	Confidence = 0.35
# Rule 90: {'paying_credits', 'savings<100'} → {'female'}
# 	Confidence = 0.35
# Rule 91: {'paying_credits', 'no_debtors'} → {'female'}
# 	Confidence = 0.36
# Rule 92: {'paying_credits', 'foreign_worker', 'savings<100'} → {'female'}
# 	Confidence = 0.36
# Rule 93: {'paying_credits', 'foreign_worker'} → {'female'}
# 	Confidence = 0.36
# Rule 94: {'paying_credits', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.36
# Rule 95: {'foreign_worker', 'bad_credit_risk'} → {'female'}
# 	Confidence = 0.36
# Rule 96: {'paying_credits', 'foreign_worker', 'no_debtors'} → {'female'}
# 	Confidence = 0.36
# Rule 97: {'paying_credits', 'foreign_worker', 'no_debtors', 'skilled_employee'} → {'female'}
# 	Confidence = 0.36
# Rule 98: {'bad_credit_risk'} → {'female'}
# 	Confidence = 0.36
# Rule 99: {'paying_credits', 'skilled_employee'} → {'female'}
# 	Confidence = 0.36
# Rule 100: {'no_debtors', 'bad_credit_risk'} → {'female'}
# 	Confidence = 0.37
# Rule 101: {'paying_credits', 'foreign_worker', 'skilled_employee'} → {'female'}
# 	Confidence = 0.37
