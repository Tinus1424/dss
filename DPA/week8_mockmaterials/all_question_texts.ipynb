# %% [markdown]
# # Data Processing Advanced Mock Exam

# %% [markdown]
# ## Question 1:
#
# Write a function `even_odd_absolute_difference` that takes a __1D numpy array of integers__ `arr` and returns an __integer__ containing the __absolute difference__ between the sum of even numbers and the sum of odd numbers in the array.
#
# *Note: You may not use any loops (for, while, etc) to solve this question.*

# %% [markdown]
# ### Testcase
# The code:
#
# ```json
# arr = numpy.array([1, 2, 3, 4, 5])  # numpy array of integers
# print(even_odd_absolute_difference(arr))
# ```
# Should print: ```3```

# %% [markdown]
# ## Question 2:
#
# Write a function called `rotate_matrix` that takes a __2D numpy array of floats__ `mat` and rotates it 90 degrees clockwise without using numpy's built-in rotation functions. The function should return the rotated __2D numpy array of floats__ as the output.
#
# *Note: You may not use any loops (for, while, etc) to solve this question.*
#
# **Hint:** For 90 degrees rotation, you can reverse the rows of the transponsed input matrix.

# %% [markdown]
# ### Testcase
# The code:
#
# ```json
# mat = numpy.array([[1.0, 2.0], [3.0, 4.0]])
# print(rotate_matrix(mat))
# ```
# Should result:
# ```
# [[3. 1.]
#  [4. 2.]]
#  ```

# %% [markdown]
# ## Question 3:
#
# Write a function `linear_algebra_ops` that takes a __2D numpy array of floats__ `mat`. The function should perform the following linear algebra operations on the input array: 1) transpose the `mat` (see [transpose](transpose.pdf)), 2) compute the dot product between `mat` and its transpose, and 3) check if the result of the dot product is invertible. If invertible, return the inversion (see [matrix inversion](Inversion.pdf)); otherwise, return a zero matrix with the same shape as the inout matrix `mat`.
#
# *Note: You may not use any loops (for, while, etc) to solve this question.*
#
# **Hint 1:** A matrix is invertible if its determinant (see [determinant](determinant.pdf)) is not zero.
#
# **Hint 2:** For more numerical stability is it is recommended to use `numpy.isclose` function (see [isclose](isclose.pdf)) to check if the determinant of a matrix is close to zero.

# %% [markdown]
# ### Testcase
#
# The code:
#
# ```json
# mat = numpy.array([[1.0, 2.0, 3.0], [3.0, 4.0, 5.0]])
# print(linear_algebra_ops(mat))
# ```
# Should result:
# ```
# [[ 2.08333333 -1.08333333]
# [-1.08333333  0.58333333]]
# ```
#
# and the code
#  ```json
# mat_singular = numpy.array([[1.0, 2.0], [2.0, 4.0]])
# print(linear_algebra_ops(mat_singular))
# ```
#
# Should result:
# ```
# [[0. 0.]
# [0. 0.]]
# ```

# %% [markdown]
# ## Question 4:
#
# Write a function `data_stats` that takes a Pandas DataFrame with arbitrary number of numerical columns (all floats) and returns a new DataFrame containing the statisics mean, 50% percentile, and standard deviation for each column. Make sure the statistics are represented in the rows (as you can see in the following example).
#
# *Note 1: You may not use any loops (for, while, etc) to solve this question.*
#
# *Note 2: Make sure the rows are in the right order (1st row: mean, 2nd row: 50%, and the third row: std). The order of columns should not change with respect to the original input DataFrame.*

# %% [markdown]
# ### Testcase
#
# The code:
#
# ```json
# df = pandas.DataFrame({'A': [1.0, 2.0, 3.0], 'B': [4.0, 5.0, 6.0]})
# print(data_stats(df))
# ```
# Should print:
# ```
#        A    B
# mean  2.0  5.0
# 50%   2.0  5.0
# std   1.0  1.0
# ```

# %% [markdown]
# ## Question 5:
#
# Write a function called `grouped_stats` that takes a Pandas DataFrame with a column `Category` (string) and a column `Value` (float). It should return a DataFrame showing the sum, mean, and count of `Value` for each category in `Category`.
#
# *Note 1: You may not use any loops (for, while, etc) to solve this question.*
#
# *Note 2: Please make sure the columns are in the right order (1st column: sum, 2nd column: mean, and the third column: count).*
#
# **Hint 1:** You may use the Pandas `agg` function (`pandas.DataFrame.agg`) to make your life much easier.

# %% [markdown]
# ### Testcase
#
# The code:
#
# ```json
# df = pandas.DataFrame({'Category': ['A', 'A', 'B', 'B'], 'Value': [10.0, 20.0, 30.0, 40.0]})
# print(grouped_stats(df))
#
# ```
# Should print:
# ```
#           sum  mean  count
# Category
# A         30.0  15.0      2
# B         70.0  35.0      2
# ```

# %% [markdown]
# ## Question 6
#
# Write code in a Jupyter notebook file (question6.ipynb) that:
#
# - loads a DataFrame from the file `sales_data.pkl` (0.1 points), which contains sales-related data with columns 'ProductID' (string), 'Month' (string), 'Region' (string), and 'SalesAmount' (float).
# - Generates a figure (0.1 points) with size [14, 5] (0.1 points) and with two subplots arranged in one row and two columns (0.1 points).
# - In the left-side subplot:
#     - Plot a line chart showing the total 'SalesAmount' for each 'Month' (1 points).
#     - Set the x-axis label to 'Month' (0.1 points) and the y-axis label to 'Total Sales Amount' (0.1 points).
#     - Add a title 'Total Sales Amount by Month' (0.1 points).
#     - Use a different color for each 'Region' in the line chart (0.1 points). You can use the default color map (thus you do not need to specifuy the colors).
#     - Add a legend displaying the region names (0.1 points).
#     - Add horizontal and vertical dashed grids (0.1 points) with opacity 0.5 (0.1 points).
# - In the right-side subplot:
#     - Plot a grouped bar chart showing the sales distribution by 'ProductID' (bars with different colours) for each 'Region' (in the x-axis) (1 points).
#     - Set the x-axis label to 'Region' (0.1 points) and the y-axis label to 'Sales Amount by Product' (0.1 points).
#     - Add a title 'Sales Distribution by Product and Region' (0.1 points).
#     - Use a different color for each 'ProductID' and add a legend (0.1 points). You can use the default color map (thus you do not need to specifuy the colors).
#     - Add only horizontal vertical (0.1 points) dashed grids (0.1 points) with opacity 0.5 (0.1 points).
# - Save the final figure in a PNG file named sales_data_visualization.png (0.1 points) with a DPI of 150 (0.1 points).
#
# *Note: You **may** use `for` loops to prepare the data for plotting.*
#
# **Hint:** Using the Pandas `groupby` function can help you to prepare data for the plotting.
#
# The final plot should look like the following figure:
# ![sales_data_visualization.png](attachment:sales_data_visualization.png)
